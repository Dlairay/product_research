# %%
import pandas as pd

# %%
import google.generativeai as genai
import os
import time

# %%
import pprint
for model in genai.list_models():
    pprint.pprint(model)
# Out:
# Model(name='models/chat-bison-001',
#       base_model_id='',
#       version='001',
#       display_name='PaLM 2 Chat (Legacy)',
#       description='A legacy text-only model optimized for chat conversations',
#       input_token_limit=4096,
#       output_token_limit=1024,
#       supported_generation_methods=['generateMessage', 'countMessageTokens'],
#       temperature=0.25,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/text-bison-001',
#       base_model_id='',
#       version='001',
#       display_name='PaLM 2 (Legacy)',
#       description='A legacy model that understands text and generates text as an output',
#       input_token_limit=8196,
#       output_token_limit=1024,
#       supported_generation_methods=['generateText', 'countTextTokens', 'createTunedTextModel'],
#       temperature=0.7,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/embedding-gecko-001',
#       base_model_id='',
# ...

# %%
df1 = pd.read_csv("gamingchairdatacleaned1.csv")
df2 = pd.read_csv("gamingchairdatacleaned2.csv")
df3 = pd.read_csv("gamingchairdatacleaned3.csv")
df4 = pd.read_csv("gamingchairdatacleaned4.csv")

# %%
df5 = pd.read_csv("gamingchairdatacleaned5.csv")
df6 = pd.read_csv("gamingchairdatacleaned6.csv")

# %%
df7 = pd.read_csv("gamingchairdatacleaned7.csv")

# %%
df7 = df7["usefulness2"]

# %%
df6
# Out:
#      Unnamed: 0                                                url  \
# 0             0  https://xrockergaming.com/blogs/news/the-ultim...
# 1             0  https://xrockergaming.com/blogs/news/the-ultim...
# 2             0  https://xrockergaming.com/blogs/news/the-ultim...
# 3             0  https://xrockergaming.com/blogs/news/the-ultim...
# 4             0  https://xrockergaming.com/blogs/news/the-ultim...
# ..          ...                                                ...
# 499          94  https://www.coherentmarketinsights.com/market-...
# 500          94  https://www.coherentmarketinsights.com/market-...
# 501          95  https://blog.secretlab.co/stories/why-buy-a-se...
# 502          96  https://desky.com.au/blogs/faqs/why-does-my-of...
# 503          96  https://desky.com.au/blogs/faqs/why-does-my-of...
#
#                                                content  \
# 0    Traditional chairs or sofas might not provide ...
# ...

# %%
df1 =df1[df1["usefulness2"] == "1\n"]
df2 =df2[df2["usefulness2"] == "1\n"]
df3 =df3[df3["usefulness2"] == "1\n"]
df4 =df4[df4["usefulness2"] == "1\n"]

# %%
df5 =df5[df5["usefulness2"] == "1\n"]
df6 =df6[df6["usefulness2"] == "1\n"]

# %%
# df1.to_csv("data/gamingchairdatacleaned1.csv",index=False)
# df2.to_csv("data/gamingchairdatacleaned2.csv",index=False)
# df3.to_csv("data/gamingchairdatacleaned3.csv",index=False)
# df4.to_csv("data/gamingchairdatacleaned4.csv",index=False)
# df5.to_csv("data/gamingchairdatacleaned5.csv",index=False)
# df6.to_csv("data/gamingchairdatacleaned6.csv",index=False)

# %%
df1 = pd.read_csv("data/gamingsentiment1.csv")
df2 = pd.read_csv("data/gamingsentiment2.csv")
df3 = pd.read_csv("data/gamingsentiment3.csv")
df4 = pd.read_csv("data/gamingsentiment4.csv")
df5 = pd.read_csv("data/gamingsentiment5.csv")
# df6 = pd.read_csv("data/gamingsentiment6.csv")

# %%
df1["sentiment"] = df1["sentiment"] .str.lower()
df1.loc[df1['sentiment'].str.contains("positive"), 'sentiment'] = "positive"
df1.loc[df1['sentiment'].str.contains("neutral"), 'sentiment'] = "neutral"
df1.loc[df1['sentiment'].str.contains("negative"), 'sentiment'] = "negative"

# %%
df2["sentiment"] = df2["sentiment"] .str.lower()
df2.loc[df2['sentiment'].str.contains("positive"), 'sentiment'] = "positive"
df2.loc[df2['sentiment'].str.contains("neutral"), 'sentiment'] = "neutral"
df2.loc[df2['sentiment'].str.contains("negative"), 'sentiment'] = "negative"

# %%
df3["sentiment"] = df3["sentiment"] .str.lower()
df3.loc[df3['sentiment'].str.contains("positive"), 'sentiment'] = "positive"
df3.loc[df3['sentiment'].str.contains("neutral"), 'sentiment'] = "neutral"
df3.loc[df3['sentiment'].str.contains("negative"), 'sentiment'] = "negative"

# %%
df4["sentiment"] = df4["sentiment"] .str.lower()
df4.loc[df4['sentiment'].str.contains("positive"), 'sentiment'] = "positive"
df4.loc[df4['sentiment'].str.contains("neutral"), 'sentiment'] = "neutral"
df4.loc[df4['sentiment'].str.contains("negative"), 'sentiment'] = "negative"

# %%
df5["sentiment"] = df5["sentiment"] .str.lower()
df5.loc[df5['sentiment'].str.contains("positive"), 'sentiment'] = "positive"
df5.loc[df5['sentiment'].str.contains("neutral"), 'sentiment'] = "neutral"
df5.loc[df5['sentiment'].str.contains("negative"), 'sentiment'] = "negative"

# %%
# df6["sentiment"] = df6["sentiment"] .str.lower()
# df6.loc[df6['sentiment'].str.contains("positive"), 'sentiment'] = "positive"
# df6.loc[df6['sentiment'].str.contains("neutral"), 'sentiment'] = "neutral"
# df6.loc[df6['sentiment'].str.contains("negative"), 'sentiment'] = "negative"

# %%
df1.to_csv("data/gamingsentimentcleaned1.csv")
df2.to_csv("data/gamingsentimentcleaned2.csv")
df3.to_csv("data/gamingsentimentcleaned3.csv")
df4.to_csv("data/gamingsentimentcleaned4.csv")
df5.to_csv("data/gamingsentimentcleaned5.csv")
# df6.to_csv("data/gamingsentimentcleaned6.csv")
